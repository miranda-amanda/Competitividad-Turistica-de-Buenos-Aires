# %% [markdown]
# #Índice de competitividad real turística multilateral y bilateral
# El índice de competitividad de Buenos Aires refleja su competitividad como un destino turístico en relación con diferentes monedas, para este analisis fueron considerados los principales países de origen del turismo receptivo, basándose en la comparación de precios y otros factores económicos.
#
# El valor base definido en diciembre de 2001 corresponde a 100, lo que significa que en diciembre de 2001, la competitividad del destino con respecto al dólar fue definida como 100.
#
# Entonces, en enero de 2002, un valor de 180 en el índice de competitividad para el dólar significa que, en comparación con diciembre de 2001 (cuando el índice era 100), la competitividad de Buenos Aires con respecto al dólar aumentó. Esto puede ocurrir debido a variaciones en los precios y el costo de vida en Buenos Aires, o factores económicos como la inflación, costos de viaje, etc.

# %% [markdown]
# ##Fórmula del Índice:
# Índice = (Ht / H0) * 100
#
# Donde:
#
# Ht: Es el índice de competitividad en un período determinado (año/mes) para cada país, que se calcula como:
#
# 𝐻𝑡 = ∑ (𝐸𝑡 × 𝑃𝐸 / 𝑃𝑁) × 𝜇0
#
# E_t es el tipo de cambio nominal (valor de la moneda extranjera con respecto al peso argentino).
#
# P_E es el Índice de Precios al Consumidor (IPC) del país de origen del turista.
#
# P_N es el Índice de Precios al Consumidor de Buenos Aires (IPCBA).
#
# μ_0 es el factor de ponderación (considera la participación del gasto de los turistas de cada país en el gasto total de los turistas extranjeros).
#
# H0: Es el valor base del índice en diciembre de 2001, donde el índice es igual a 100. Este valor sirve como referencia para calcular la evolución del índice a lo largo del tiempo.

# %% [markdown]
# ## Descripción de los Componentes:
# Tipo de Cambio Nominal (E): Representa el valor de la moneda extranjera respecto al peso argentino. Si el tipo de cambio nominal de una moneda aumenta, significa que la moneda extranjera se fortalece frente al peso argentino.
#
# Índice de Precios al Consumidor (P): Se utilizan dos índices de precios:
#
# P_E (Índice de Precios del país extranjero): Refleja el nivel de precios en el país de origen del turista.
# P_N (Índice de Precios de Buenos Aires): Refleja el nivel de precios en la ciudad de Buenos Aires.
# El cálculo del índice de competitividad compara la inflación local (en Buenos Aires) con la inflación en el país de origen del turista. Si los precios en Buenos Aires aumentan más que en los países de origen de los turistas, la competitividad del destino disminuye.
#
# Factor de Ponderación (μ_0): Este factor es una ponderación que considera el gasto relativo de los turistas de cada país. Es decir, el peso de cada país en el cálculo depende de cuánto dinero gastan sus turistas en Buenos Aires.

# %% [markdown]
# ## Cómo Funciona el Cálculo del Índice e Interpretación:
# Para cada país de origen de los turistas, se calcula el valor del tipo de cambio nominal y el Índice de Precios al Consumidor.
# Para cada período (mes o año), se calcula el índice de competitividad para cada moneda, ponderado por el gasto relativo de los turistas de cada país.
# El valor Ht es la suma de estos índices, y la fórmula del índice Ht/H0*100 compara la situación de cada período con la referencia base de diciembre de 2001 (donde el índice es igual a 100).
# El índice final multilateral representa la competitividad de Buenos Aires para todos los turistas extranjeros en relación con los costos en sus países de origen.
#
# Índice > 100: Indica que los costos en Buenos Aires aumentaron para los turistas en relación con el valor base de 2001. La ciudad se volvió menos competitiva para los turistas (en términos de sus monedas).
#
# Índice < 100: Indica que los costos disminuyeron, haciendo que Buenos Aires sea más competitiva para los turistas, ya que se volvió más barata para ellos.
#
#
#
# Este cálculo tiene en cuenta no solo los tipos de cambio y la inflación, sino también el comportamiento del gasto de los turistas. Así, el Índice de Competitividad Real Turística Multilateral ofrece una visión integral de cómo la ciudad de Buenos Aires se comporta como destino turístico en términos de costos para los turistas extranjeros a lo largo del tiempo.

# %% [markdown]
# ## Preparing data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/miranda-amanda/Competitividad-Turistica-de-Buenos-Aires/main/competitividad_turistica_datos.csv')

# %%
df.head()
# Out:
#    anio  mes  multilateral         usd        real  peso_chileno        euro  \
# 0  2001   12    100.000000  100.000000  100.000000    100.000000  100.000000
# 1  2002    1    174.555824  178.902950  172.005179    171.675287  173.768640
# 2  2002    2    201.087015  206.293901  200.989461    198.543507  200.911545
# 3  2002    3    270.644440  274.725794  276.191447    271.516881  268.850234
# 4  2002    4    239.734857  245.192586  233.031066    243.771564  249.005135
#
#    libra_esterlina     guarani  nuevo_shekel  peso_mexicano  peso_uruguayo
# 0       100.000000  100.000000    100.000000     100.000000     100.000000
# 1       173.350426  172.629046    172.205096     179.716828     174.942536
# 2       200.350785  193.434017    199.261775     208.154902     195.247463
# 3       267.263221  261.685350    257.492367     279.059517     258.666471
# 4       243.629026  236.543966    225.541218     240.098006     210.577074

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   anio             276 non-null    int64
#  1   mes              276 non-null    int64
#  2   multilateral     276 non-null    float64
#  3   usd              276 non-null    float64
#  4   real             276 non-null    float64
#  5   peso_chileno     276 non-null    float64
#  6   euro             276 non-null    float64
#  7   libra_esterlina  276 non-null    float64
#  8   guarani          276 non-null    float64
#  9   nuevo_shekel     276 non-null    float64
#  10  peso_mexicano    276 non-null    float64
#  11  peso_uruguayo    276 non-null    float64
#  12  fecha            276 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(10), int64(2)
# memory usage: 28.2 KB

# %%
df['fecha'] = pd.to_datetime(df['anio'].astype(str) + '-' + df['mes'].astype(str), format='%Y-%m')
df.head()
# Out:
#    anio  mes  multilateral         usd        real  peso_chileno        euro  \
# 0  2001   12    100.000000  100.000000  100.000000    100.000000  100.000000
# 1  2002    1    174.555824  178.902950  172.005179    171.675287  173.768640
# 2  2002    2    201.087015  206.293901  200.989461    198.543507  200.911545
# 3  2002    3    270.644440  274.725794  276.191447    271.516881  268.850234
# 4  2002    4    239.734857  245.192586  233.031066    243.771564  249.005135
#
#    libra_esterlina     guarani  nuevo_shekel  peso_mexicano  peso_uruguayo  \
# 0       100.000000  100.000000    100.000000     100.000000     100.000000
# 1       173.350426  172.629046    172.205096     179.716828     174.942536
# 2       200.350785  193.434017    199.261775     208.154902     195.247463
# 3       267.263221  261.685350    257.492367     279.059517     258.666471
# 4       243.629026  236.543966    225.541218     240.098006     210.577074
#
#        fecha
# 0 2001-12-01
# 1 2002-01-01
# ...

# %% [markdown]
# ## EDA

# %%
# Exibindo estatísticas descritivas
df.describe()
# Out:
#               anio         mes  multilateral         usd        real  \
# count   276.000000  276.000000    276.000000  276.000000  276.000000
# mean   2012.916667    6.500000    255.455222  226.124169  273.964284
# min    2001.000000    1.000000    100.000000  100.000000  100.000000
# 25%    2007.000000    3.750000    225.929594  190.691588  243.579829
# 50%    2013.000000    6.500000    250.301545  203.962410  270.687452
# 75%    2019.000000    9.250000    275.194646  267.399916  315.486211
# max    2024.000000   12.000000    447.754002  430.255149  431.716279
# std       6.651065    3.458323     39.286271   48.456664   52.490842
#
#        peso_chileno        euro  libra_esterlina     guarani  nuevo_shekel  \
# count    276.000000  276.000000       276.000000  276.000000    276.000000
# mean     249.207382  289.053089       230.537047  291.906469    232.818081
# min      100.000000  100.000000       100.000000  100.000000    100.000000
# ...

# %% [markdown]
# Distribuição das Variáveis
# Você pode usar histogramas ou gráficos de densidade para examinar como as variáveis estão distribuídas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma para as variáveis numéricas
df[['multilateral', 'usd', 'real', 'peso_chileno', 'euro', 'libra_esterlina', 'guarani', 'nuevo_shekel', 'peso_mexicano', 'peso_uruguayo']].hist(bins=20, figsize=(15,10))
plt.suptitle('Distribuição das Variáveis', fontsize=16)
plt.show()

# %% [markdown]
# La imagen muestra la distribución de los índices de competitividad le las monedas de los principales países de origen del turismo receptivo de Buenos Aires a lo largo del período 2001–2024. Las principales interpretaciones de los histogramas:
#
# * La distribución **Multilateral** parece ser asimétrica, con la mayoría de los
# valores concentrados entre 200 y 300. Hay un menor número de valores por encima de 300, lo que sugiere que los períodos de alta competitividad multilateral fueron menos frecuentes.
#
# * El **Dólar (USD)** presenta una distribución concentrada entre 150 y 250, con un pico claro, lo que sugiere una relativa estabilidad en el índice de competitividad del dólar estadounidense.
#
# * La distribución del **Real Brasileño (BRL)** tiene una forma similar a la del USD, con mayor densidad entre 200 y 300. Esto podría indicar que el índice del real experimentó fluctuaciones significativas, pero permaneció dentro de un rango delimitado.
#
# * Puede ser observada una distribución más plana del **Peso Chileno**, con valores dispersos principalmente entre 200 y 300, lo que indica una mayor variación en comparación con otras monedas.
#
# * El **Euro** Presenta una distribución con un pico alrededor de 250, pero con valores significativos en rangos más bajos, lo que indica variaciones en la competitividad a lo largo del tiempo.
#
# * La **Libra Esterlina (GBP)** Tiene una distribución más simétrica y centrada, con la mayoría de los valores entre 200 y 300, lo que sugiere estabilidad en el índice de competitividad de la libra.
#
# * El **Guaraní (PYG)** presenta una distribución similar a la del peso chileno, con valores más dispersos entre 200 y 300, lo que sugiere una mayor variabilidad.
#
# * El **Nuevo Shekel (ILS)** presenta una distribución algo más plana y dispersa, con valores más bajos en comparación con otras monedas, lo que indica menor competitividad en algunos períodos.
#
# * **Peso Mexicano (MXN):** Presenta un pico más definido, indicando que la mayoría de los valores se concentraron entre 150 y 250, con menor dispersión en comparación con monedas como el peso chileno.
#
# * La distribución del **Peso Uruguayo (UYU)** muestra múltiples picos (bimodal o multimodal), lo que indica posibles cambios bruscos en el índice de competitividad a lo largo del tiempo.
#
# De este modo, es posible concluir que la mayoría de las monedas presenta valores concentrados entre 200 y 300, lo que podría indicar que la competitividad turística de Buenos Aires en relación con estos países mostró un comportamiento estable en la mayor parte del período.  Algunas monedas, como el peso chileno y el peso uruguayo, tienen distribuciones más dispersas, lo que sugiere una mayor volatilidad en el índice de competitividad. El comportamiento del índice a lo largo del tiempo podría reflejar cambios macroeconómicos, como crisis cambiarias, fluctuaciones inflacionarias o eventos externos que impactaron el turismo.

# %%
# Gráfico de densidade para comparar a distribuição das variáveis
df[['multilateral', 'usd', 'real', 'peso_chileno', 'euro', 'libra_esterlina', 'guarani', 'nuevo_shekel', 'peso_mexicano', 'peso_uruguayo']].plot(kind='density', figsize=(15,10))
plt.title('Distribuição das Variáveis', fontsize=16)
plt.show()

# %% [markdown]
# El gráfico de densidad de las variables numéricas representa la distribución de los índices de competitividad turística para diferentes monedas. Cada curva en representa una variable (moneda) y muestra la densidad estimada de sus valores a lo largo del tiempo. El eje x representa los valores del índice de competitividad (base diciembre de 2001 = 100). El eje y representa la densidad, que está normalizada para que el área bajo cada curva sea igual a 1.
#
# - **Multilateral (línea azul):** Tiene una distribución más centralizada, con mayor densidad en torno a 200–300, indicando que los índices multilateralmente competitivos se concentraron en este rango durante el período.
# - **USD (dólar) (línea naranja):** Muestra un pico definido en el rango de 200–250, lo que sugiere mayor estabilidad y menor variabilidad en el índice de competitividad del dólar.
# - **Real (BRL) (línea verde):** Presenta una densidad distribuida en torno a 200–300, similar a la curva multilateral, pero ligeramente desplazada.
# - **Peso Mexicano (línea amarilla):** Tiene el pico más alto y estrecho en comparación con las otras monedas, lo que sugiere menor variabilidad en el índice.
# - **Peso Uruguayo (línea celeste):** Es la curva más dispersa, con múltiples picos y alta densidad en valores más altos, lo que indica, nuevamente, la gran variabilidad.
# - **Euro y Libra Esterlina:** Ambas tienen picos más suaves, lo que sugiere distribuciones menos concentradas que el USD o el peso mexicano.
# - **Guaraní (línea rosa):** Presenta una distribución más amplia, similar al peso uruguayo, pero con mayor densidad en valores más bajos.
# - **Nuevo Shekel:** Una curva más dispersa, con densidad moderada, lo que indica mayor variabilidad.
#
# Aún es posible acresentar que algunas monedas (como USD, peso mexicano y euro) tienen distribuciones más estrechas y concentradas, lo que indica menor variabilidad a lo largo del tiempo. Monedas como el peso uruguayo, el guaraní y el real muestran distribuciones más amplias e incluso multimodales, reflejando la presencia de períodos de mayor inestabilidad económica.  Además, el índice multilateral está más alineado con monedas como el real y el euro, probablemente porque estos mercados tienen una mayor interconexión económica con Buenos Aires.

# %% [markdown]
# #Visualização de Tendências ao Longo do Tempo
# Crie gráficos de linha para explorar como os índices das moedas evoluíram ao longo do tempo, com destaque para o índice multilateral.

# %%
# Gráfico de linha para os índices de competitividade
plt.figure(figsize=(12,6))
sns.lineplot(x='fecha', y='multilateral', data=df, label='Multilateral')
sns.lineplot(x='fecha', y='usd', data=df, label='USD')
sns.lineplot(x='fecha', y='euro', data=df, label='EUR')
sns.lineplot(x='fecha', y='real', data=df, label='BRL')
plt.title('Evolução dos Índices de Competitividade Turística')
plt.xlabel('Ano')
plt.ylabel('Índice de Competitividade')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# El gráfico presenta la evolución de los índices de competitividad turística para el índice multilateral a lo largo del tiempo y tres monedas específicas: USD (dólar estadounidense), EUR (euro) y BRL (real brasileño). Los picos de caída del índice de competitividad turística reflejan una apreciación del peso argentino. Esta interpretación se basa en la definición del índice de competitividad: cuanto menor es el índice, menos competitiva se vuelve la ciudad para los turistas que usan esa moneda. Esto ocurre porque los costos relativos para esos turistas aumentan.
#
# * **Multilateral (línea azul):**  Muestra una evolución relativamente estable a lo largo del tiempo, con una ligera tendencia al alza hasta aproximadamente 2020, cuando se observa mayor volatilidad.  Refleja un promedio ponderado de los índices bilaterales, mostrando menos fluctuaciones extremas en comparación con las monedas individuales.
#
# * **USD (línea naranja):**  Presenta una caída constante entre 2004 y aproximadamente 2011, estabilizándose en niveles más bajos. A partir de 2020, se observan picos de volatilidad, posiblemente vinculados a choques económicos globales (pandemia, guerra en Ucrania, etc.).
#
# * **EUR (línea verde):** Exhibe un comportamiento más dinámico, con variaciones frecuentes. Después de 2010, muestra un aumento gradual hasta 2020, seguido de fluctuaciones más pronunciadas.  Este comportamiento podría estar relacionado con crisis económicas (como la crisis de deuda europea) y las relaciones comerciales entre Europa y Argentina.
#
# * **BRL (línea roja):** Es la moneda con mayor volatilidad, con fuertes picos y caídas a lo largo del tiempo. Se destaca una caída pronunciada entre 2015 y 2016, seguida de una recuperación, posiblemente asociada con crisis económicas en Brasil (como el impeachment y la inestabilidad política).  Los picos después de 2020 pueden atribuirse a factores macroeconómicos regionales.
#
# El periodo **2001–2002** los índices inician en niveles altos, pero el real cae rápidamente, reflejando la crisis económica argentina y el fin de la convertibilidad (abandono del tipo de cambio fijo con el dólar). En **2015–2016** el Real experimenta una caída significativa debido a la recesión económica brasileña y la inestabilidad política.  En el año **2020** todos los índices muestran un aumento de volatilidad, reflejando los impactos de la pandemia de COVID-19 en las economías globales y en la competitividad turística. Entre **2023–2024** es posible observar grandes fluctuaciones, especialmente en el Real y el Euro, posiblemente relacionadas con cambios recientes en el mercado financiero, inflación o políticas económicas globales.
#
# **Perspectivas sobre Competitividad Turística**
# El **Real** es el más volátil, lo que indica que la competitividad turística de Argentina frente a Brasil fue más sensible a factores internos y externos.   El Dólar muestra un comportamiento más estable, lo que indica una relación más predecible en la competitividad bilateral con Estados Unidos. El **Índice Multilateral** proporciona una visión menos volátil, aunque alineada con las principales tendencias económicas globales.

# %% [markdown]
# #4. Análise de Correlação
# Você pode calcular e visualizar a matriz de correlação para entender como as diferentes moedas estão relacionadas entre si e ao índice multilateral.

# %%
# Matriz de correlação
corr = df[['multilateral', 'usd', 'real', 'peso_chileno', 'euro', 'libra_esterlina', 'guarani', 'nuevo_shekel', 'peso_mexicano', 'peso_uruguayo']].corr()

# Visualizando a matriz de correlação
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação entre os Índices de Competitividade')
plt.show()

# %% [markdown]
# La matriz de correlación mide la relación lineal entre los índices de competitividad turística para las monedas durante el período analizado (2001–2024).
#
# Es posicle observar una lta correlación entre el Índice Multilateral y el Peso Chileno (0.95). El índice multilateral, que representa un promedio ponderado de varias monedas, está fuertemente correlacionado con el índice basado en el peso chileno. Esto sugiere que las fluctuaciones del peso chileno tienen un impacto significativo en la competitividad multilateral. Al relacionar con el gráfico de densidad, esta relación puede deberse a la relativa estabilidad de los valores del peso chileno, que tienden a seguir tendencias globales.
#
# Existe una correlación moderada del Real Brasileño con otras monedas. El índice del real brasileño muestra correlaciones bajas o moderadas con las demás monedas, por ejemplo, 0.09 con USD, 0.39 con el euro y 0.64 con el peso chileno.
# Este comportamiento más independiente puede explicarse por factores específicos del mercado brasileño, como fluctuaciones económicas locales o políticas económicas más autónomas en comparación con otros países.
#
# El dólar estadounidense (USD) tiene una correlación muy alta con el nuevo shekel israelí (0.94) y con el índice multilateral (0.83). Esto refleja la influencia global del dólar como moneda de referencia, que afecta la competitividad internacional de las economías dependientes de él.
#
# Sobre el Peso Argentino y las monedas regionales Guaraní y Peso Uruguayo, el índice multilateral también presenta alta correlación, de un 0.86 y 0.85 respectivamente.Esta fuerte relación puede atribuirse a la interdependencia económica entre los países del Mercosur. Aunque el peso argentino muestra volatilidad extrema en el tiempo, como se observa en el gráfico de evolución, esta no parece afectar significativamente la correlación con monedas regionales.
#
# Há una baja correlación del Real Brasileño y la Libra Esterlina con otras monedas, como el nuevo shekel (0.21). Esto indica que el comportamiento del real está poco relacionado con monedas menos relevantes para Brasil, ya sea a nivel regional o global.
#
#
# La matriz de correlación resalta las interconexiones económicas y cómo los índices de competitividad están influenciados por dependencias regionales y por monedas globales clave como el dólar y el euro. Las monedas regionales (como el peso uruguayo y el guaraní) muestran relaciones fuertes debido a la proximidad económica y comercial.
#
# Las correlaciones bajas del real reflejan su dinámica más autónoma, mientras que las altas correlaciones del dólar y el peso chileno con el índice multilateral subrayan su relevancia en la competitividad turística de Buenos Aires.
#
#     [ En el Gráfico de Evolución de los Indices, se observa cómo algunas monedas, como el peso chileno y el euro, siguen patrones similares, lo que refleja altas correlaciones. Por otro lado, monedas con comportamientos más independientes, como el real, mantienen correlaciones más bajas con el resto. ]

# %%
# Boxplot para visualizar outliers
plt.figure(figsize=(12,6))
sns.boxplot(data=df[['multilateral', 'usd', 'real', 'peso_chileno', 'euro', 'libra_esterlina', 'guarani', 'nuevo_shekel', 'peso_mexicano', 'peso_uruguayo']])
plt.title('Análise de Outliers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# En el gráfico de análisis de valores atípicos los outliers están representados por puntos individuales fuera del rango de los bigotes de cada boxplot. Al analisar los patrones e implicaciones:
#
# A respecto del Dólar (USD), existen valores extremos por encima de 400, indicando picos inusuales en la competitividad del peso argentino frente al dólar. Estos podrían estar relacionados con desvalorizaciones abruptas del peso durante eventos de crisis económica.
#
# Los outliers del Euro se concentran en su mayor parte superior por encima de 400, reflejando fluctuaciones extremas frente a la moneda europea. Esto podría deberse a episodios de alta volatilidad cambiaria en Argentina, como las crisis de deuda o ajustes monetarios.
#
# Con relacion al Guarani (Paraguay) se observan valores atípicos elevados, por encima de 400, sugiriendo que en ciertos momentos Buenos Aires resultó considerablemente más barata para turistas paraguayos.
#
# A respecto del Peso Chileno y Peso Uruguayo, los outliers en la parte superior (más de 450) indican períodos de extrema competitividad frente a estas monedas.
# Estas variaciones pueden estar relacionadas con dinámicas regionales específicas, como crisis cambiarias o políticas monetarias en estos países.
#
#
# El Peso Mexicano presenta valores atípicos tanto en la parte inferior (menos de 100) como en la superior. Esto indica fluctuaciones significativas en la competitividad bilateral con México, posiblemente debido a variaciones en políticas económicas o cambios en los mercados cambiarios.
#
# Los outliers suelen reflejar eventos atipicos como crisis económicas, com desvalorizaciones drásticas del peso argentino, como las ocurridas en 2002, 2014, 2018 y 2020. Episodios en las políticas monetarias, como la eliminación de controles cambiarios (2015) o restricciones económicas que afectaron la paridad cambiaria. Ademas por acontecimentos en contextos regionales, como variaciones en las monedas vecinas.
#
# *Es importante destacar que estos outliers pueden desviar métricas como medias y medianas, lo que lleva a una representación menos precisa de la tendencia central en los datos.
#
# Las implicaciones de los outliers son diversas. Los outliers altos representan momentos en que Buenos Aires fue extremadamente atractiva para turistas debido a devaluaciones del peso argentino. Los bajo indican períodos en que la ciudad perdió competitividad, posiblemente por apreciaciones del peso o incrementos en los costos internos.
#
#
#     Investigar estos valores atípicos permite contextualizar momentos de alta o baja competitividad dentro de la evolución económica de Buenos Aires. Determinar si deben ser incluidos, excluidos o tratados como casos especiales depende del objetivo de la investigación.

# %%
# Agrupar por ano e calcular a média
df_ano = df.groupby(df['fecha'].dt.year).mean()

# Gráfico de tendências anuais
plt.figure(figsize=(12,6))
sns.lineplot(x=df_ano.index, y='multilateral', data=df_ano, label='Multilateral')
sns.lineplot(x=df_ano.index, y='usd', data=df_ano, label='USD')
sns.lineplot(x=df_ano.index, y='euro', data=df_ano, label='EUR')
sns.lineplot(x=df_ano.index, y='real', data=df_ano, label='BRL')
plt.title('Tendências Anuais dos Índices de Competitividade Turística')
plt.xlabel('Ano')
plt.ylabel('Índice de Competitividade')
plt.legend()
plt.show()
